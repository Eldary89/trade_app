# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import math

# %%
data=pd.read_csv('eurgbp_d.csv')

# %%
print(data.head(10))
# Out:
#          date     open     high      low    close       atr        rsi
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690

# %%
#high-low
data['h-l']= data['high'] - data['low']


#entry level buy orders
data['lev1b']= data['high']- data['h-l']*0.236
data['lev2b']= data['high']- data['h-l']*0.382
data['lev3b']= data['high']- data['h-l']*0.50
data['lev4b']= data['high']- data['h-l']*0.618
data['lev5b']= data['high']- data['h-l']*0.7647

#entry level sell orders
data['lev1s']= data['low']+ data['h-l']*0.236
data['lev2s']= data['low']+ data['h-l']*0.382
data['lev3s']= data['low']+ data['h-l']*0.50
data['lev4s']= data['low']+ data['h-l']*0.618
data['lev5s']= data['low']+ data['h-l']*0.7647

print(data.head(10))
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b     lev3b     lev4b     lev5b     lev1s  \
# 0  0.00235  0.699095  0.698752  0.698475  0.698198  0.697853  0.697855
# ...

# %%
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b     lev3b     lev4b     lev5b     lev1s  \
# 0  0.00235  0.699095  0.698752  0.698475  0.698198  0.697853  0.697855
# ...

# %%
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b  ...  Sell_Lev2  Sell_Lev3  Sell_Lev4  \
# 0  0.00235  0.699095  0.698752  ...   0.000000    0.00000        0.0
# ...

# %%
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b  ...  Buy_Lev1  Buy_Lev2  Buy_Lev3  Buy_Lev4  \
# 0  0.00235  0.699095  0.698752  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %%
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b  ...  Buy_Lev1  Buy_Lev2  Buy_Lev3  Buy_Lev4  \
# 0  0.00235  0.699095  0.698752  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %%
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b  ...  Sell_Lev1  Sell_Lev2  Sell_Lev3  \
# 0  0.00235  0.699095  0.698752  ...   0.000000   0.000000        0.0
# ...

# %%
# Out:
#          date     open     high      low    close       atr        rsi  \
# 0  14/03/2005  0.69890  0.69965  0.69730  0.69855  0.003425  65.792899
# 1  15/03/2005  0.69865  0.69905  0.69475  0.69555  0.003492  57.182835
# 2  16/03/2005  0.69530  0.69700  0.69420  0.69657  0.003439  59.140697
# 3  17/03/2005  0.69660  0.69710  0.69445  0.69484  0.003378  54.581967
# 4  18/03/2005  0.69475  0.69585  0.69301  0.69335  0.003337  50.939960
# 5  21/03/2005  0.69336  0.69535  0.69160  0.69379  0.003369  51.959376
# 6  22/03/2005  0.69370  0.69575  0.69303  0.69370  0.003319  51.722632
# 7  23/03/2005  0.69380  0.69630  0.69245  0.69474  0.003360  54.313121
# 8  24/03/2005  0.69460  0.69615  0.69183  0.69227  0.003434  47.758639
# 9  25/03/2005  0.69250  0.69360  0.69198  0.69265  0.003294  48.782690
#
#        h-l     lev1b     lev2b  ...  Sell_Lev2  Sell_Lev3  Sell_Lev4  \
# 0  0.00235  0.699095  0.698752  ...   0.000000    0.00000        0.0
# ...
